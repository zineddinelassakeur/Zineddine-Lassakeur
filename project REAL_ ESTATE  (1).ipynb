# %%
import pandas as pd 
DATA=  pd.read_csv ("data- real estate.csv")
DATA
DATA.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
#data preprocessing
DATA.info
# Out:
# <bound method DataFrame.info of         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 506  0.98765   0.0  12.50     0  0.561  6.980  89.0  2.0980    3  320
# 507  0.23456   0.0  12.50     0  0.561  6.980  76.0  2.6540    3  320
# 508  0.44433   0.0  12.50     0  0.561  6.123  98.0  2.9870    3  320
# 509  0.77763   0.0  12.70     0  0.561  6.222  34.0  2.5430    3  329
# 510  0.65432   0.0  12.80     0  0.561  6.760  67.0  2.9870    3  345
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
DATA.isnull().sum
# Out:
# <bound method DataFrame.sum of       CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 506  False  False  False  False  False  False  False  False  False  False
# 507  False  False  False  False  False  False  False  False  False  False
# 508  False  False  False  False  False  False  False  False  False  False
# 509  False  False  False  False  False  False  False  False  False  False
# 510  False  False  False  False  False  False  False  False  False  False
#
#      PTRATIO      B  LSTAT   MEDV
# ...

# %%
DATA.isnull().sum().sum()
# Out:
# 5

# %%
DATA.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         5
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
mean_RM =(DATA["RM"].mean())
mean_RM
# Out:
# 6.287588932806333

# %%
DATA["RM"].fillna(mean_RM,inplace=True)

# %%
DATA.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
#data visualization
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(21,8))
sns.heatmap(DATA.corr(), annot=True)

# %%
import seaborn as sns
  
sns.distplot(DATA["AGE"])         
plt.show()

# %%
import seaborn as sns
  
sns.distplot(DATA["DIS"])         
plt.show()

# %%
import seaborn as sns
  
sns.distplot(DATA["TAX"])         
plt.show()

# %%
sns.scatterplot(data=DATA, x="DIS", y="TAX")

# %%
sns.scatterplot(data=DATA, x="RM", y="TAX")

# %%
sns.boxplot(x=DATA["MEDV"])

# %%
sns.boxplot(x=DATA["LSTAT"])

# %%
plt.figure(figsize=(6,12))
sns.pairplot(DATA)
plt.show()

# %%
#Linear Regression
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
x=DATA["RM"].values.reshape(-1,1)
y=DATA["TAX"]
print(x,y)
# Out:
# [[6.575     ]
#  [6.421     ]
#  [7.185     ]
#  [6.998     ]
#  [7.147     ]
#  [6.43      ]
#  [6.012     ]
#  [6.172     ]
#  [5.631     ]
#  [6.004     ]
#  [6.28758893]
#  [6.009     ]
#  [5.889     ]
#  [5.949     ]
#  [6.096     ]
#  [5.834     ]
#  [5.935     ]
#  [5.99      ]
#  [5.456     ]
#  [5.727     ]
#  [5.57      ]
#  [5.965     ]
#  [6.142     ]
#  [5.813     ]
#  [5.924     ]
#  [5.599     ]
#  [5.813     ]
#  [6.047     ]
#  [6.495     ]
#  [6.674     ]
#  [5.713     ]
#  [6.072     ]
#  [5.95      ]
#  [5.701     ]
#  [6.096     ]
#  [6.28758893]
#  [5.841     ]
#  [5.85      ]
#  [5.966     ]
#  [6.595     ]
#  [7.024     ]
#  [6.77      ]
#  [6.169     ]
#  [6.211     ]
#  [6.069     ]
#  [5.682     ]
#  [5.786     ]
#  [6.03      ]
#  [5.399     ]
#  [5.602     ]
#  [5.963     ]
#  [6.115     ]
#  [6.511     ]
#  [5.998     ]
#  [5.888     ]
#  [7.249     ]
#  [6.383     ]
#  [6.816     ]
#  [6.145     ]
#  [5.927     ]
#  [5.741     ]
#  [5.966     ]
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)
from sklearn.linear_model import LinearRegression
linear_regess= LinearRegression()
linear_regess.fit(x_train,y_train)
prediict =linear_regess.predict(x_test)
plt. plot (x_train,linear_regess.predict(x_train),color="black")
plt.scatter(x,y, color="red")

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,prediict)
mse
# Out:
# 26122.58520958492

# %%
from sklearn.metrics import r2_score
rs=r2_score(y_test,prediict)
rs
# Out:
# 0.06021478882104303

# %%
#Multi-linear Regression
import numpy as np
from sklearn.linear_model import LinearRegression
x=DATA[["CRIM","LSTAT","MEDV"]]
y=DATA["TAX"]
from sklearn.linear_model import LinearRegression
linear_regess= LinearRegression()
linear_regess.fit(x_train,y_train)
prediict =linear_regess.predict(x_test)
plt. plot (x_test,linear_regess.predict(x_test),color="red")
plt. scatter (x_train,y_train,color="blue")

# %%
#Polynomial Regression 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures 

from sklearn.metrics import mean_squared_error
from sklearn import metrics
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40) 

lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) 
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  11949.336030983633
# R squared:  0.6091727151614064

# %%
x=DATA["RM"].values.reshape(-1,1)
y=DATA["TAX"]
poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="r")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")
